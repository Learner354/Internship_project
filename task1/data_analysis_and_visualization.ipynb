# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('creditcard.csv')
df.head(5)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
df['Class'].value_counts(normalize=True)*100
# Out:
# Class
# 0    99.827251
# 1     0.172749
# Name: proportion, dtype: float64

# %%
sns.countplot(df['Class'].value_counts())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 sns.countplot(df['Class'].value_counts())
#
# NameError: name 'sns' is not defined

# %%
(492/284807)*100
# Out:
# 0.1727485630620034

# %%
df.hist(bins=50,figsize=(20,15))
plt.tight_layout()

# %%
df.skew()
# Out:
# Time      -0.035568
# V1        -3.280667
# V2        -4.624866
# V3        -2.240155
# V4         0.676292
# V5        -2.425901
# V6         1.826581
# V7         2.553907
# V8        -8.521944
# V9         0.554680
# V10        1.187141
# V11        0.356506
# V12       -2.278401
# V13        0.065233
# V14       -1.995176
# V15       -0.308423
# V16       -1.100966
# V17       -3.844914
# V18       -0.259880
# V19        0.109192
# V20       -2.037155
# V21        3.592991
# V22       -0.213258
# V23       -5.875140
# V24       -0.552499
# V25       -0.415793
# V26        0.576693
# V27       -1.170209
# V28       11.192091
# Amount    16.977724
# Class     23.997579
# dtype: float64

# %%
plt.figure(figsize=(12,6))
sns.boxplot(data=df)
plt.xticks(rotation=90)
plt.title('Feature Boxplots for Outlier Detection')
plt.show()

# %%
from scipy import stats
z_scores = np.abs(stats.zscore(df.select_dtypes(include=['float64', 'int64'])))
outliers = (z_scores > 3).sum()
outliers
# Out:
# Time         0
# V1        3701
# V2        4318
# V3        1987
# V4        3094
# V5        2945
# V6        4652
# V7        3401
# V8        4221
# V9        2293
# V10       3488
# V11        684
# V12       3393
# V13       1192
# V14       3380
# V15       1254
# V16       2077
# V17       2515
# V18       1685
# V19       3399
# V20       4645
# V21       4064
# V22       1222
# V23       3364
# V24        657
# V25       2809
# V26       1047
# V27       4771
# V28       3264
# Amount    4076
# Class      492
# dtype: int64

# %%
# Check ranges
print("\nFeature ranges (max - min):")
print(df.max() - df.min())

# Check standard deviations
print("\nFeature standard deviations:")
print(df.std())

# Visual comparison
plt.figure(figsize=(12,6))
df.plot(kind='box', vert=False, logy=True)  # Log scale helps visualize wide ranges
plt.title('Feature Ranges Comparison (Log Scale)')
plt.show()
# Out:
# Feature ranges (max - min):
# Time      172792.000000
# V1            58.862440
# V2            94.773457
# V3            57.708148
# V4            22.558515
# V5           148.544973
# V6            99.462131
# V7           164.146736
# V8            93.223927
# V9            29.029061
# V10           48.333399
# V11           16.816387
# V12           26.532107
# V13           12.918764
# V14           29.741092
# V15           13.376686
# V16           31.444966
# V17           34.416326
# V18           14.539815
# V19           12.805499
# V20           93.918625
# V21           62.033221
# V22           21.436234
# V23           67.336147
# V24            7.421176
# V25           17.814986
# V26            6.121896
# V27           54.177877
# V28           49.277892
# Amount     25691.160000
# Class          1.000000
# dtype: float64
#
# Feature standard deviations:
# Time      47488.145955
# V1            1.958696
# V2            1.651309
# V3            1.516255
# ...

# %%
# Correlation matrix
plt.figure(figsize=(15,10))
corr_matrix = df.corr()
sns.heatmap(corr_matrix, cmap='coolwarm', center=0)
plt.title('Feature Correlation Matrix')
plt.show()

# Correlation with target
print("\nCorrelation with Class:")
print(corr_matrix['Class'].sort_values(ascending=False))
# Out:
# Correlation with Class:
# Class     1.000000
# V11       0.154876
# V4        0.133447
# V2        0.091289
# V21       0.040413
# V19       0.034783
# V20       0.020090
# V8        0.019875
# V27       0.017580
# V28       0.009536
# Amount    0.005632
# V26       0.004455
# V25       0.003308
# V22       0.000805
# V23      -0.002685
# V15      -0.004223
# V13      -0.004570
# V24      -0.007221
# Time     -0.012323
# V6       -0.043643
# V5       -0.094974
# V9       -0.097733
# V1       -0.101347
# V18      -0.111485
# V7       -0.187257
# V3       -0.192961
# V16      -0.196539
# V10      -0.216883
# V12      -0.260593
# V14      -0.302544
# V17      -0.326481
# Name: Class, dtype: float64

# %%
# Time feature analysis
fraud=df[df['Class']==1]
plt.figure(figsize=(12, 6))
sns.distplot(fraud['Time'], bins=100, color='red')
plt.title('Distribution of Transaction Times for Fraud Cases')
plt.xlabel('Time (seconds since first transaction)')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\Junaid\AppData\Local\Temp\ipykernel_13472\3771646805.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(fraud['Time'], bins=100, color='red')

# %%
plt.figure(figsize=(12, 6))
sns.distplot(fraud['Amount'], bins=50, color='red')
plt.title('Distribution of Transaction Amounts for Fraud Cases')
plt.xlabel('Amount')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\Junaid\AppData\Local\Temp\ipykernel_13472\1882912008.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(fraud['Amount'], bins=50, color='red')

# %%
# Save key statistics to a dictionary
eda_results = {
    'shape': df.shape,
    'missing_values': df.isnull().sum().to_dict(),
    'class_distribution': df['Class'].value_counts().to_dict(),
    'dtypes': df.dtypes.to_dict(),
    'stats': df.describe().to_dict()
}

# You can save this to a JSON file for your report
import json
def convert(o):
    if isinstance(o, np.generic):
        return o.item()
    raise TypeError

# Save to JSON
with open('eda_results.json', 'w') as f:
    json.dump(eda_results, f, default=convert)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 19
#      17 # Save to JSON
#      18 with open('eda_results.json', 'w') as f:
# ---> 19     json.dump(eda_results, f, default=convert)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\json\__init__.py:179, in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     173     iterable = cls(skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     174         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     175         separators=separators,
#     176         default=default, sort_keys=sort_keys, **kw).iterencode(obj)
#     177 # could accelerate with writelines in some versions of Python, at
#     178 # a debuggability cost
# --> 179 for chunk in iterable:
#     180     fp.write(chunk)
#
# ...
